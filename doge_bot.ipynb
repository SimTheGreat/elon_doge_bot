# %%
#importing modules
import tweepy 
import csv
import pandas as pd
import requests       
import json            
import numpy as np        
import matplotlib.pyplot as plt 
import datetime as dt  
from binance import Client, ThreadedWebsocketManager, ThreadedDepthCacheManager
import time

# %%
#Twitter API keys
consumer_key = "5CxzSYF8Jk0igvJFoa0dgppA7"
consumer_secret = "CxlQYeByx8DjMCJfcDnBQfqFbtLnio8B332HO3yLyQESXrv4v3"
access_key = "1278657842468323339-yt2LqOvHWWwcnmlhPYi1kLRwbcNELm"
access_secret = "wcDmN1okqgw7IgR1WmLKr5muuNqXiB3IH23w6FgGPnuWe"

# %%
def get_all_tweets(screen_name):
    #Twitter only allows access to a users most recent 3240 tweets with this method
    
    #authorize twitter, initialize tweepy
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
    
    #initialize a list to hold all the tweepy Tweets
    alltweets = []  
    alltweets_minus_replys=[]
    
    
    new_tweets = api.user_timeline(screen_name = screen_name,count=200)
    
    #save most recent tweets
    alltweets.extend(new_tweets)
    
    #save the id of the oldest tweet less one
    oldest = alltweets[-1].id - 1
    
    #keep grabbing tweets until there are no tweets left to grab
    while len(new_tweets) > 0:
        print(f"getting tweets before {oldest}")
        
        #all subsiquent requests use the max_id param to prevent duplicates
        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
        
        #save most recent tweets
        alltweets.extend(new_tweets)
        
        #update the id of the oldest tweet less one
        oldest = alltweets[-1].id-1
        
        print(f"...{len(alltweets)} tweets downloaded so far")
    
    #transform the tweepy tweets into a 2D array that will populate the csv 
    outtweets = [[tweet.id_str, tweet.created_at, tweet.text] for tweet in alltweets]
    for i in outtweets:
        tweet = api.get_status(i[0])
        if tweet.in_reply_to_status_id is not None:
        # Tweet is a reply
            pass
            
        else:
    # Tweet is not a reply
            alltweets_minus_replys.append(i)
        

    #write the csv  
    with open(f'new_{screen_name}_tweets.csv', 'w') as f:
        writer = csv.writer(f)
        writer.writerow(["id","created_at","text"])
        writer.writerows(alltweets_minus_replys)
    
    pass

# %%
#doge releated tweets

def doge_releated_tweets():
    
    for j in data['text']:
        if 'doge'   in j or 'Doge'in j:
            row=data[data['text']==j]
            data_doge = data_doge.append(row)

# %%
def buy_doge(amount):
    client = Client("vnucqmbHFnSTL9lIEbZtIrk58u9vmjc9Pm4Ox1OXJfgu2xCM2u1PR8UT5JxstkKS", "nQeEjwcOzowPps7MMDo2TFUNlrSsrv3aUccrOdE9mREPMXSOC72C6J2eSldK3GjW")
    order = client.create_order(
        symbol="DOGEUSDT",
        side=Client.SIDE_BUY,
        type=Client.ORDER_TYPE_MARKET,
        quantity=amount)

# %%
def sell_doge():
    order = client.create_order(
        symbol="DOGEUSDT",
        side=Client.SIDE_SELL,
        type=Client.ORDER_TYPE_MARKET,
        quantity=50)

# %%
while True:
    if __name__ == '__main__':

        get_all_tweets("elonmusk")
    
    data = pd.read_csv('new_elonmusk_tweets.csv')
    data_doge=pd.DataFrame()
    if len(data_doge)==0:
        print('no doge related tweet in the last ', len(data), ' tweets')
        time.sleep(86400)
    elif data_doge['created_at'][0][:-5]==datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")[:-5]:
            print('tweet found')
            time.sleep(600)
            sell_doge()
            time.sleep(86400)
# Out:
# getting tweets before 1408247691537223680
# ...50 tweets downloaded so far
# getting tweets before 1407077949774442498
# ...50 tweets downloaded so far
# no doge related tweet in the last  10  tweets
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-8effd7f78e73> in <module>
#       8     if len(data_doge)==0:
#       9         print('no doge related tweet in the last ', len(data), ' tweets')
# ---> 10         time.sleep(86400)
#      11     else:
#      12         if data_doge['created_at'][0][:-5]==datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")[:-5]:
#
# KeyboardInterrupt:

# %%
data
# Out:
#                     id           created_at  \
# 0  1409152382345244684  2021-06-27 14:11:23
# 1  1408558492009566214  2021-06-25 22:51:28
# 2  1408380216653844480  2021-06-25 11:03:04
# 3  1408375014261395462  2021-06-25 10:42:24
# 4  1408251692811014145  2021-06-25 02:32:22
# 5  1408247691537223681  2021-06-25 02:16:28
# 6  1408246196603346947  2021-06-25 02:10:31
# 7  1407868620680699908  2021-06-24 01:10:10
# 8  1407143586718785537  2021-06-22 01:09:09
# 9  1407143457383141376  2021-06-22 01:08:38
#
#                                                 text
# 0                            https://t.co/HStnXM0zmn
# 1  Starlink simultaneously active users just exce...
# 2                   My Shiba Inu will be named Floki
# 3       Timing is everything https://t.co/B6HDB5kS4G
# 4  RT @m_tijn: Accidentally deleted this tweet, s...
# 5            RT @archillect: https://t.co/vVjYch9uvb
# 6  How many Bitcoin maxis does it take to screw i...
# ...
